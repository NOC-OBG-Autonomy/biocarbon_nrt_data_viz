# %%
# Import needed modules

import pandas as pd
import numpy as np
from tqdm import tqdm
import os
from pathlib import Path
import xarray as xr
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from datetime import datetime
import cartopy.feature as cfeature
import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point
import matplotlib.colors as colors
import geopandas as gpd
from urllib.request import urlretrieve
import requests
from glob import glob
import os
from datetime import datetime, timedelta
import json
import sys
import math
from geopy.distance import distance
from matplotlib.colors import to_rgba
from collections import defaultdict

# %%
parent_dir    = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
data_dir      = os.path.join(parent_dir, 'data')
satellite_dir = os.path.join(data_dir, 'satellite')
output_dir    = os.path.join(parent_dir, 'Output/sat_plot')
NEODASS_dir   = os.path.join(satellite_dir, 'NEODASS')
floats_dir    = os.path.join(parent_dir, 'Data/Floats')

# %%
# Plotting preferences

# Global
min_lon = -35
max_lon = -5
min_lat = 55
max_lat = 66

# Float colors
# For additional floats, add the name (as it appears in the 'Float_positions.csv') and color you'd like (as a hexcode)
float_colors = {
        '4903532':  '#B4184C',
        'navis102': '#F5A300',
        '1902637':  '#0000E0',
        'navis101': '#FBFF1F'}

# CHLA
CHLA_color           = 'YlGnBu_r'
CHLA_plot_as_log     = True # Default True
CHLA_plot_lim_max    = 10   # Default 10
CHLA_plot_lim_min    = 0.1  # Default 0.1

# SST
SST_color            = 'YlOrRd'
SST_plot_as_log      = False # Default False
SST_plot_lim_max     = 15    # Default 15
SST_plot_lim_min     = 5     # Default 5

# SSH
SSH_color            = 'RdBu'
SSH_plot_as_log      = False # Default False
SSH_plot_lim_max     = 0.5   # Default  0.5
SSH_plot_lim_min     = -0.5  # Default -0.5

# Surface Currents
SSC_color            = 'YlGnBu_r'
SSC_plot_as_log      = False # Default False
SSC_plot_lim_max     = 5   # Default 5
SSC_plot_lim_min     = 0   # Default 0

# BBP
BBP_color            = 'YlGnBu_r'
BBP_plot_as_log      = True
BBP_plot_lim_max     = 0.1
BBP_plot_lim_min     = 0.0001

# %%
# Function to generate points on a circle centered at (lat, lon) with a given radius
def generate_circle_points(lat, lon, radius_km, num_points=360):
    angles = np.linspace(0, 360, num_points)
    circle_points = []
    for angle in angles:
        point = distance(kilometers=radius_km).destination((lat, lon), angle)
        circle_points.append((point.latitude, point.longitude))
    
    return np.array(circle_points)

# Load shape files for bathymetry:
#first_line_path = 'c:\\Users\\flapet\\OneDrive - NOC\\Documents\\NRT_viz\\biocarbon_nrt_data_viz/Data/ne_10m_bathymetry_all/ne_10m_bathymetry_J_1000.shp'
#second_line_path = 'c:\\Users\\flapet\\OneDrive - NOC\\Documents\\NRT_viz\\biocarbon_nrt_data_viz/Data/ne_10m_bathymetry_all/ne_10m_bathymetry_I_2000.shp'

first_line_path  = 'C:\\Users\\hanshil\\Documents\\GitHub\\biocarbon_nrt_data_viz\\data\\bathymetry\\ne_10m_bathymetry_J_1000.shp'
second_line_path = 'C:\\Users\\hanshil\\Documents\\GitHub\\biocarbon_nrt_data_viz\\data\\bathymetry\\ne_10m_bathymetry_I_2000.shp'

gdf_1000 = gpd.read_file(first_line_path)
gdf_2000 = gpd.read_file(second_line_path)

# %%
### Plotting most recent data from CMEMS
## List most recent files

# List to store matching file names
matching_files = []

# Loop through the files in the directory
for filename in os.listdir(NEODASS_dir):
    if filename.endswith('.nc') and f'-1d-' in filename:
        matching_files.append(filename)

print(matching_files)

## List variables from these files
# Dictionary to store files by their base names (excluding '_a_' or '_b_') and key variables
file_dict = {}

for file in matching_files:
    # Identify the base name by removing '_a' or '_b' if present
    base_name = file.replace('_a', '_').replace('_b', '_')
    if base_name not in file_dict:
        file_dict[base_name] = {}
    filepath  = os.path.join(NEODASS_dir, file)
    ds        = xr.open_dataset(filepath)
    variables = list(ds.data_vars.keys())
    
    # Find the key variable excluding 'longitude' and 'latitude'
    key_variable = None
    for var in variables:
        if 'longitude' not in var.lower() and 'latitude' not in var.lower():
            key_variable = var
            break
    
    if key_variable:
        file_dict[base_name][file] = key_variable
    
    ds.close()

# Print the results
for base_name, files in file_dict.items():
    for file, key_variable in files.items():
        print(f'File: {file}')
        print(f'Base Name: {base_name}')
        print(f'Key Variable: {key_variable}')

    filepath  = os.path.join(NEODASS_dir, file)
    dataset = xr.open_dataset(filepath)

    # Print global attributes
    print("Global attributes:")
    for attr_name, attr_value in dataset.attrs.items():
        print(f"  {attr_name}: {attr_value}")

    # Print variable attributes
    print("\nVariable attributes:")
    for var_name, var in dataset.variables.items():
        print(f"Variable: {var_name}")
        for attr_name, attr_value in var.attrs.items():
            print(f"  {attr_name}: {attr_value}")

# Group files by variable category
var_dict = {'chl': [], 'temp': [], 'sla': [], 'adt': [], 'bbp': []}

for base_name, files in file_dict.items():
    for file, data_var in files.items():
        var_name_lower = data_var.lower()
        if 'chl' in var_name_lower:
            var_dict['chl'].append((file, data_var))
        elif 'temp' in var_name_lower:
            var_dict['temp'].append((file, data_var))
        elif 'sla' in var_name_lower:
            var_dict['sla'].append((file, data_var))
        elif 'adt' in var_name_lower:
            var_dict['adt'].append((file, data_var))
        elif 'bbp' in var_name_lower:
            var_dict['bbp'].append((file, data_var))
# Out:
# ['cmems_sea_level-sla-1d-20240520_20240520-nrt.nc', 'cmems_sea_level-sla-1d-20240521_20240521-nrt.nc', 'cmems_sea_level-sla-1d-20240522_20240522-nrt.nc', 'cmems_sea_level-sla-1d-20240523_20240523-nrt.nc', 'cmems_sea_level-sla-1d-20240524_20240524-nrt.nc', 'cmems_sea_level-sla-1d-20240525_20240525-nrt.nc', 'cmems_sea_level-sla-1d-20240526_20240526-nrt.nc', 'cmems_sea_level-sla-1d-20240527_20240527-nrt.nc', 'olci_a_1km-CHL_OC4ME-1d-20240520_20240520-nrt.nc', 'olci_a_1km-CHL_OC4ME-1d-20240521_20240521-nrt.nc', 'olci_a_1km-CHL_OC4ME-1d-20240522_20240522-nrt.nc', 'olci_a_1km-CHL_OC4ME-1d-20240523_20240523-nrt.nc', 'olci_a_1km-CHL_OC4ME-1d-20240524_20240524-nrt.nc', 'olci_a_1km-CHL_OC4ME-1d-20240525_20240525-nrt.nc', 'olci_a_1km-CHL_OC4ME-1d-20240526_20240526-nrt.nc', 'olci_a_1km-CHL_OC4ME-1d-20240527_20240527-nrt.nc', 'olci_b_1km-CHL_OC4ME-1d-20240520_20240520-nrt.nc', 'olci_b_1km-CHL_OC4ME-1d-20240521_20240521-nrt.nc', 'olci_b_1km-CHL_OC4ME-1d-20240522_20240522-nrt.nc', 'olci_b_1km-CHL_OC4ME-1d-20240523_20240523-nrt.nc', 'olci_b_1km-CHL_OC4ME-1d-20240524_20240524-nrt.nc', 'olci_b_1km-CHL_OC4ME-1d-20240525_20240525-nrt.nc', 'olci_b_1km-CHL_OC4ME-1d-20240526_20240526-nrt.nc', 'olci_b_1km-CHL_OC4ME-1d-20240527_20240527-nrt.nc', 'slstr_a-sea_surface_temperature-1d-20240520_20240520-nrt.nc', 'slstr_a-sea_surface_temperature-1d-20240521_20240521-nrt.nc', 'slstr_a-sea_surface_temperature-1d-20240522_20240522-nrt.nc', 'slstr_a-sea_surface_temperature-1d-20240523_20240523-nrt.nc', 'slstr_a-sea_surface_temperature-1d-20240524_20240524-nrt.nc', 'slstr_a-sea_surface_temperature-1d-20240525_20240525-nrt.nc', 'slstr_a-sea_surface_temperature-1d-20240526_20240526-nrt.nc', 'slstr_a-sea_surface_temperature-1d-20240527_20240527-nrt.nc', 'slstr_b-sea_surface_temperature-1d-20240520_20240520-nrt.nc', 'slstr_b-sea_surface_temperature-1d-20240521_20240521-nrt.nc', 'slstr_b-sea_surface_temperature-1d-20240522_20240522-nrt.nc', 'slstr_b-sea_surface_temperature-1d-20240523_20240523-nrt.nc', 'slstr_b-sea_surface_temperature-1d-20240524_20240524-nrt.nc', 'slstr_b-sea_surface_temperature-1d-20240525_20240525-nrt.nc', 'slstr_b-sea_surface_temperature-1d-20240526_20240526-nrt.nc', 'slstr_b-sea_surface_temperature-1d-20240527_20240527-nrt.nc', 'viirs_noaa20-chl_oc5ci-1d-20240520_20240520-nrt.nc', 'viirs_noaa20-chl_oc5ci-1d-20240521_20240521-nrt.nc', 'viirs_noaa20-chl_oc5ci-1d-20240522_20240522-nrt.nc', 'viirs_noaa20-chl_oc5ci-1d-20240523_20240523-nrt.nc', 'viirs_noaa20-chl_oc5ci-1d-20240524_20240524-nrt.nc', 'viirs_noaa20-chl_oc5ci-1d-20240525_20240525-nrt.nc', 'viirs_noaa20-chl_oc5ci-1d-20240526_20240526-nrt.nc', 'viirs_noaa20-chl_oc5ci-1d-20240527_20240527-nrt.nc', 'viirs_suomi-chl_oc5_pic-1d-20240520_20240520-nrt.nc', 'viirs_suomi-chl_oc5_pic-1d-20240521_20240521-nrt.nc', 'viirs_suomi-chl_oc5_pic-1d-20240522_20240522-nrt.nc', 'viirs_suomi-chl_oc5_pic-1d-20240523_20240523-nrt.nc', 'viirs_suomi-chl_oc5_pic-1d-20240524_20240524-nrt.nc', 'viirs_suomi-chl_oc5_pic-1d-20240525_20240525-nrt.nc', 'viirs_suomi-chl_oc5_pic-1d-20240526_20240526-nrt.nc', 'viirs_suomi-chl_oc5_pic-1d-20240527_20240527-nrt.nc']
# File: cmems_sea_level-sla-1d-20240520_20240520-nrt.nc
# Base Name: cmems_sea_level-sla-1d-20240520_20240520-nrt.nc
# Key Variable: sla
# Global attributes:
#   Conventions: CF-1.6
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   cdm_data_type: Grid
#   comment: Sea Surface Height measured by Altimetry and derived variables
#   contact: servicedesk.cmems@mercator-ocean.eu
#   creator_email: servicedesk.cmems@mercator-ocean.eu
#   creator_name: CMEMS - Sea Level Thematic Assembly Center
#   creator_url: http://marine.copernicus.eu
#   date_created: 2023-11-24T00:53:06Z
#   date_issued: 2023-11-24T00:53:06Z
#   date_modified: 2023-11-24T00:53:06Z
#   geospatial_lat_max: 89.875
#   geospatial_lat_min: -89.875
#   geospatial_lat_resolution: 0.25
#   geospatial_lat_units: degrees_north
#   geospatial_lon_max: 179.875
#   geospatial_lon_min: -179.875
#   geospatial_lon_resolution: 0.25
#   geospatial_lon_units: degrees_east
#   geospatial_vertical_max: 0.0
#   geospatial_vertical_min: 0.0
#   geospatial_vertical_positive: down
#   geospatial_vertical_resolution: point
#   geospatial_vertical_units: m
#   history: 2023-11-24 00:53:07Z: Creation
#   institution: CLS, CNES
#   keywords: Oceans > Ocean Topography > Sea Surface Height
#   keywords_vocabulary: NetCDF COARDS Climate and Forecast Standard Names
#   license: http://marine.copernicus.eu/web/27-service-commitments-and-licence.php
#   platform: Altika, Cryosat-2 New Orbit, Haiyang-2B, Jason-3 Interleaved, Sentinel-3A, Sentinel-3B, Sentinel-6A
#   processing_level: L4
#   product_version: vDec2021
#   project: COPERNICUS MARINE ENVIRONMENT MONITORING SERVICE (CMEMS)
#   references: http://marine.copernicus.eu
#   software_version: 19.2.0_DUACS_DT2021_baseline
#   source: Altimetry measurements
#   ssalto_duacs_comment: Sentinel-6A is the reference mission used for the altimeter inter-calibration processing
#   standard_name_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention Standard Name Table v37
#   summary: SSALTO/DUACS Near-Real-Time Level-4 sea surface height and derived variables measured by multi-satellite altimetry observations over Global Ocean.
#   time_coverage_duration: P1D
#   time_coverage_end: 2023-11-24T12:00:00Z
#   time_coverage_resolution: P1D
#   time_coverage_start: 2023-11-23T12:00:00Z
#   title: NRT merged all satellites Global Ocean Gridded SSALTO/DUACS Sea Surface Height L4 product and derived variables
#   copernicusmarine_version: 1.2.0
#
# Variable attributes:
# Variable: sla
#   ancillary_variables: err_sla
#   comment: The sea level anomaly is the sea surface height above mean sea surface; it is referenced to the [1993, 2012] period; see the product user manual for details
#   grid_mapping: crs
#   long_name: Sea level anomaly
#   standard_name: sea_surface_height_above_sea_level
#   units: m
# Variable: latitude
#   axis: Y
#   bounds: lat_bnds
#   long_name: Latitude
#   standard_name: latitude
#   units: degrees_north
#   valid_max: 64.875
#   valid_min: 49.125
# Variable: longitude
#   axis: X
#   bounds: lon_bnds
#   long_name: Longitude
#   standard_name: longitude
#   units: degrees_east
#   valid_max: -9.375
#   valid_min: -36.625
# Variable: time
#   valid_min: 27168
#   valid_max: 27168
# File: cmems_sea_level-sla-1d-20240521_20240521-nrt.nc
# Base Name: cmems_sea_level-sla-1d-20240521_20240521-nrt.nc
# Key Variable: sla
# Global attributes:
#   Conventions: CF-1.6
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   cdm_data_type: Grid
#   comment: Sea Surface Height measured by Altimetry and derived variables
#   contact: servicedesk.cmems@mercator-ocean.eu
#   creator_email: servicedesk.cmems@mercator-ocean.eu
#   creator_name: CMEMS - Sea Level Thematic Assembly Center
#   creator_url: http://marine.copernicus.eu
#   date_created: 2023-11-24T00:53:06Z
#   date_issued: 2023-11-24T00:53:06Z
#   date_modified: 2023-11-24T00:53:06Z
#   geospatial_lat_max: 89.875
#   geospatial_lat_min: -89.875
#   geospatial_lat_resolution: 0.25
#   geospatial_lat_units: degrees_north
#   geospatial_lon_max: 179.875
#   geospatial_lon_min: -179.875
#   geospatial_lon_resolution: 0.25
#   geospatial_lon_units: degrees_east
#   geospatial_vertical_max: 0.0
#   geospatial_vertical_min: 0.0
#   geospatial_vertical_positive: down
#   geospatial_vertical_resolution: point
#   geospatial_vertical_units: m
#   history: 2023-11-24 00:53:07Z: Creation
#   institution: CLS, CNES
#   keywords: Oceans > Ocean Topography > Sea Surface Height
#   keywords_vocabulary: NetCDF COARDS Climate and Forecast Standard Names
#   license: http://marine.copernicus.eu/web/27-service-commitments-and-licence.php
#   platform: Altika, Cryosat-2 New Orbit, Haiyang-2B, Jason-3 Interleaved, Sentinel-3A, Sentinel-3B, Sentinel-6A
#   processing_level: L4
#   product_version: vDec2021
#   project: COPERNICUS MARINE ENVIRONMENT MONITORING SERVICE (CMEMS)
#   references: http://marine.copernicus.eu
#   software_version: 19.2.0_DUACS_DT2021_baseline
#   source: Altimetry measurements
#   ssalto_duacs_comment: Sentinel-6A is the reference mission used for the altimeter inter-calibration processing
#   standard_name_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention Standard Name Table v37
#   summary: SSALTO/DUACS Near-Real-Time Level-4 sea surface height and derived variables measured by multi-satellite altimetry observations over Global Ocean.
#   time_coverage_duration: P1D
#   time_coverage_end: 2023-11-24T12:00:00Z
#   time_coverage_resolution: P1D
#   time_coverage_start: 2023-11-23T12:00:00Z
#   title: NRT merged all satellites Global Ocean Gridded SSALTO/DUACS Sea Surface Height L4 product and derived variables
#   copernicusmarine_version: 1.2.0
#
# Variable attributes:
# Variable: sla
#   ancillary_variables: err_sla
#   comment: The sea level anomaly is the sea surface height above mean sea surface; it is referenced to the [1993, 2012] period; see the product user manual for details
#   grid_mapping: crs
#   long_name: Sea level anomaly
#   standard_name: sea_surface_height_above_sea_level
#   units: m
# Variable: latitude
#   axis: Y
#   bounds: lat_bnds
#   long_name: Latitude
#   standard_name: latitude
#   units: degrees_north
#   valid_max: 64.875
#   valid_min: 49.125
# Variable: longitude
#   axis: X
#   bounds: lon_bnds
#   long_name: Longitude
#   standard_name: longitude
#   units: degrees_east
#   valid_max: -9.375
#   valid_min: -36.625
# Variable: time
#   valid_min: 27169
#   valid_max: 27169
# File: cmems_sea_level-sla-1d-20240522_20240522-nrt.nc
# Base Name: cmems_sea_level-sla-1d-20240522_20240522-nrt.nc
# Key Variable: sla
# Global attributes:
#   Conventions: CF-1.6
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   cdm_data_type: Grid
#   comment: Sea Surface Height measured by Altimetry and derived variables
#   contact: servicedesk.cmems@mercator-ocean.eu
#   creator_email: servicedesk.cmems@mercator-ocean.eu
#   creator_name: CMEMS - Sea Level Thematic Assembly Center
#   creator_url: http://marine.copernicus.eu
#   date_created: 2023-11-24T00:53:06Z
#   date_issued: 2023-11-24T00:53:06Z
#   date_modified: 2023-11-24T00:53:06Z
#   geospatial_lat_max: 89.875
#   geospatial_lat_min: -89.875
#   geospatial_lat_resolution: 0.25
#   geospatial_lat_units: degrees_north
#   geospatial_lon_max: 179.875
#   geospatial_lon_min: -179.875
#   geospatial_lon_resolution: 0.25
#   geospatial_lon_units: degrees_east
#   geospatial_vertical_max: 0.0
#   geospatial_vertical_min: 0.0
#   geospatial_vertical_positive: down
#   geospatial_vertical_resolution: point
#   geospatial_vertical_units: m
#   history: 2023-11-24 00:53:07Z: Creation
#   institution: CLS, CNES
#   keywords: Oceans > Ocean Topography > Sea Surface Height
#   keywords_vocabulary: NetCDF COARDS Climate and Forecast Standard Names
#   license: http://marine.copernicus.eu/web/27-service-commitments-and-licence.php
#   platform: Altika, Cryosat-2 New Orbit, Haiyang-2B, Jason-3 Interleaved, Sentinel-3A, Sentinel-3B, Sentinel-6A
#   processing_level: L4
#   product_version: vDec2021
#   project: COPERNICUS MARINE ENVIRONMENT MONITORING SERVICE (CMEMS)
#   references: http://marine.copernicus.eu
#   software_version: 19.2.0_DUACS_DT2021_baseline
#   source: Altimetry measurements
#   ssalto_duacs_comment: Sentinel-6A is the reference mission used for the altimeter inter-calibration processing
#   standard_name_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention Standard Name Table v37
#   summary: SSALTO/DUACS Near-Real-Time Level-4 sea surface height and derived variables measured by multi-satellite altimetry observations over Global Ocean.
#   time_coverage_duration: P1D
#   time_coverage_end: 2023-11-24T12:00:00Z
#   time_coverage_resolution: P1D
#   time_coverage_start: 2023-11-23T12:00:00Z
#   title: NRT merged all satellites Global Ocean Gridded SSALTO/DUACS Sea Surface Height L4 product and derived variables
#   copernicusmarine_version: 1.2.0
#
# Variable attributes:
# Variable: sla
#   ancillary_variables: err_sla
#   comment: The sea level anomaly is the sea surface height above mean sea surface; it is referenced to the [1993, 2012] period; see the product user manual for details
#   grid_mapping: crs
#   long_name: Sea level anomaly
#   standard_name: sea_surface_height_above_sea_level
#   units: m
# Variable: latitude
#   axis: Y
#   bounds: lat_bnds
#   long_name: Latitude
#   standard_name: latitude
#   units: degrees_north
#   valid_max: 64.875
#   valid_min: 49.125
# Variable: longitude
#   axis: X
#   bounds: lon_bnds
#   long_name: Longitude
#   standard_name: longitude
#   units: degrees_east
#   valid_max: -9.375
#   valid_min: -36.625
# Variable: time
#   valid_min: 27170
#   valid_max: 27170
# File: cmems_sea_level-sla-1d-20240523_20240523-nrt.nc
# Base Name: cmems_sea_level-sla-1d-20240523_20240523-nrt.nc
# Key Variable: sla
# Global attributes:
#   Conventions: CF-1.6
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   cdm_data_type: Grid
#   comment: Sea Surface Height measured by Altimetry and derived variables
#   contact: servicedesk.cmems@mercator-ocean.eu
#   creator_email: servicedesk.cmems@mercator-ocean.eu
#   creator_name: CMEMS - Sea Level Thematic Assembly Center
#   creator_url: http://marine.copernicus.eu
#   date_created: 2023-11-24T00:53:06Z
#   date_issued: 2023-11-24T00:53:06Z
#   date_modified: 2023-11-24T00:53:06Z
#   geospatial_lat_max: 89.875
#   geospatial_lat_min: -89.875
#   geospatial_lat_resolution: 0.25
#   geospatial_lat_units: degrees_north
#   geospatial_lon_max: 179.875
#   geospatial_lon_min: -179.875
#   geospatial_lon_resolution: 0.25
#   geospatial_lon_units: degrees_east
#   geospatial_vertical_max: 0.0
#   geospatial_vertical_min: 0.0
#   geospatial_vertical_positive: down
#   geospatial_vertical_resolution: point
#   geospatial_vertical_units: m
#   history: 2023-11-24 00:53:07Z: Creation
#   institution: CLS, CNES
#   keywords: Oceans > Ocean Topography > Sea Surface Height
#   keywords_vocabulary: NetCDF COARDS Climate and Forecast Standard Names
#   license: http://marine.copernicus.eu/web/27-service-commitments-and-licence.php
#   platform: Altika, Cryosat-2 New Orbit, Haiyang-2B, Jason-3 Interleaved, Sentinel-3A, Sentinel-3B, Sentinel-6A
#   processing_level: L4
#   product_version: vDec2021
#   project: COPERNICUS MARINE ENVIRONMENT MONITORING SERVICE (CMEMS)
#   references: http://marine.copernicus.eu
#   software_version: 19.2.0_DUACS_DT2021_baseline
#   source: Altimetry measurements
#   ssalto_duacs_comment: Sentinel-6A is the reference mission used for the altimeter inter-calibration processing
#   standard_name_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention Standard Name Table v37
#   summary: SSALTO/DUACS Near-Real-Time Level-4 sea surface height and derived variables measured by multi-satellite altimetry observations over Global Ocean.
#   time_coverage_duration: P1D
#   time_coverage_end: 2023-11-24T12:00:00Z
#   time_coverage_resolution: P1D
#   time_coverage_start: 2023-11-23T12:00:00Z
#   title: NRT merged all satellites Global Ocean Gridded SSALTO/DUACS Sea Surface Height L4 product and derived variables
#   copernicusmarine_version: 1.2.0
#
# Variable attributes:
# Variable: sla
#   ancillary_variables: err_sla
#   comment: The sea level anomaly is the sea surface height above mean sea surface; it is referenced to the [1993, 2012] period; see the product user manual for details
#   grid_mapping: crs
#   long_name: Sea level anomaly
#   standard_name: sea_surface_height_above_sea_level
#   units: m
# Variable: latitude
#   axis: Y
#   bounds: lat_bnds
#   long_name: Latitude
#   standard_name: latitude
#   units: degrees_north
#   valid_max: 64.875
#   valid_min: 49.125
# Variable: longitude
#   axis: X
#   bounds: lon_bnds
#   long_name: Longitude
#   standard_name: longitude
#   units: degrees_east
#   valid_max: -9.375
#   valid_min: -36.625
# Variable: time
#   valid_min: 27171
#   valid_max: 27171
# File: cmems_sea_level-sla-1d-20240524_20240524-nrt.nc
# Base Name: cmems_sea_level-sla-1d-20240524_20240524-nrt.nc
# Key Variable: sla
# Global attributes:
#   Conventions: CF-1.6
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   cdm_data_type: Grid
#   comment: Sea Surface Height measured by Altimetry and derived variables
#   contact: servicedesk.cmems@mercator-ocean.eu
#   creator_email: servicedesk.cmems@mercator-ocean.eu
#   creator_name: CMEMS - Sea Level Thematic Assembly Center
#   creator_url: http://marine.copernicus.eu
#   date_created: 2023-11-24T00:53:06Z
#   date_issued: 2023-11-24T00:53:06Z
#   date_modified: 2023-11-24T00:53:06Z
#   geospatial_lat_max: 89.875
#   geospatial_lat_min: -89.875
#   geospatial_lat_resolution: 0.25
#   geospatial_lat_units: degrees_north
#   geospatial_lon_max: 179.875
#   geospatial_lon_min: -179.875
#   geospatial_lon_resolution: 0.25
#   geospatial_lon_units: degrees_east
#   geospatial_vertical_max: 0.0
#   geospatial_vertical_min: 0.0
#   geospatial_vertical_positive: down
#   geospatial_vertical_resolution: point
#   geospatial_vertical_units: m
#   history: 2023-11-24 00:53:07Z: Creation
#   institution: CLS, CNES
#   keywords: Oceans > Ocean Topography > Sea Surface Height
#   keywords_vocabulary: NetCDF COARDS Climate and Forecast Standard Names
#   license: http://marine.copernicus.eu/web/27-service-commitments-and-licence.php
#   platform: Altika, Cryosat-2 New Orbit, Haiyang-2B, Jason-3 Interleaved, Sentinel-3A, Sentinel-3B, Sentinel-6A
#   processing_level: L4
#   product_version: vDec2021
#   project: COPERNICUS MARINE ENVIRONMENT MONITORING SERVICE (CMEMS)
#   references: http://marine.copernicus.eu
#   software_version: 19.2.0_DUACS_DT2021_baseline
#   source: Altimetry measurements
#   ssalto_duacs_comment: Sentinel-6A is the reference mission used for the altimeter inter-calibration processing
#   standard_name_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention Standard Name Table v37
#   summary: SSALTO/DUACS Near-Real-Time Level-4 sea surface height and derived variables measured by multi-satellite altimetry observations over Global Ocean.
#   time_coverage_duration: P1D
#   time_coverage_end: 2023-11-24T12:00:00Z
#   time_coverage_resolution: P1D
#   time_coverage_start: 2023-11-23T12:00:00Z
#   title: NRT merged all satellites Global Ocean Gridded SSALTO/DUACS Sea Surface Height L4 product and derived variables
#   copernicusmarine_version: 1.2.0
#
# Variable attributes:
# Variable: sla
#   ancillary_variables: err_sla
#   comment: The sea level anomaly is the sea surface height above mean sea surface; it is referenced to the [1993, 2012] period; see the product user manual for details
#   grid_mapping: crs
#   long_name: Sea level anomaly
#   standard_name: sea_surface_height_above_sea_level
#   units: m
# Variable: latitude
#   axis: Y
#   bounds: lat_bnds
#   long_name: Latitude
#   standard_name: latitude
#   units: degrees_north
#   valid_max: 64.875
#   valid_min: 49.125
# Variable: longitude
#   axis: X
#   bounds: lon_bnds
#   long_name: Longitude
#   standard_name: longitude
#   units: degrees_east
#   valid_max: -9.375
#   valid_min: -36.625
# Variable: time
#   valid_min: 27172
#   valid_max: 27172
# File: cmems_sea_level-sla-1d-20240525_20240525-nrt.nc
# Base Name: cmems_sea_level-sla-1d-20240525_20240525-nrt.nc
# Key Variable: sla
# Global attributes:
#   Conventions: CF-1.6
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   cdm_data_type: Grid
#   comment: Sea Surface Height measured by Altimetry and derived variables
#   contact: servicedesk.cmems@mercator-ocean.eu
#   creator_email: servicedesk.cmems@mercator-ocean.eu
#   creator_name: CMEMS - Sea Level Thematic Assembly Center
#   creator_url: http://marine.copernicus.eu
#   date_created: 2023-11-24T00:53:06Z
#   date_issued: 2023-11-24T00:53:06Z
#   date_modified: 2023-11-24T00:53:06Z
#   geospatial_lat_max: 89.875
#   geospatial_lat_min: -89.875
#   geospatial_lat_resolution: 0.25
#   geospatial_lat_units: degrees_north
#   geospatial_lon_max: 179.875
#   geospatial_lon_min: -179.875
#   geospatial_lon_resolution: 0.25
#   geospatial_lon_units: degrees_east
#   geospatial_vertical_max: 0.0
#   geospatial_vertical_min: 0.0
#   geospatial_vertical_positive: down
#   geospatial_vertical_resolution: point
#   geospatial_vertical_units: m
#   history: 2023-11-24 00:53:07Z: Creation
#   institution: CLS, CNES
#   keywords: Oceans > Ocean Topography > Sea Surface Height
#   keywords_vocabulary: NetCDF COARDS Climate and Forecast Standard Names
#   license: http://marine.copernicus.eu/web/27-service-commitments-and-licence.php
#   platform: Altika, Cryosat-2 New Orbit, Haiyang-2B, Jason-3 Interleaved, Sentinel-3A, Sentinel-3B, Sentinel-6A
#   processing_level: L4
#   product_version: vDec2021
#   project: COPERNICUS MARINE ENVIRONMENT MONITORING SERVICE (CMEMS)
#   references: http://marine.copernicus.eu
#   software_version: 19.2.0_DUACS_DT2021_baseline
#   source: Altimetry measurements
#   ssalto_duacs_comment: Sentinel-6A is the reference mission used for the altimeter inter-calibration processing
#   standard_name_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention Standard Name Table v37
#   summary: SSALTO/DUACS Near-Real-Time Level-4 sea surface height and derived variables measured by multi-satellite altimetry observations over Global Ocean.
#   time_coverage_duration: P1D
#   time_coverage_end: 2023-11-24T12:00:00Z
#   time_coverage_resolution: P1D
#   time_coverage_start: 2023-11-23T12:00:00Z
#   title: NRT merged all satellites Global Ocean Gridded SSALTO/DUACS Sea Surface Height L4 product and derived variables
#   copernicusmarine_version: 1.2.0
#
# Variable attributes:
# Variable: sla
#   ancillary_variables: err_sla
#   comment: The sea level anomaly is the sea surface height above mean sea surface; it is referenced to the [1993, 2012] period; see the product user manual for details
#   grid_mapping: crs
#   long_name: Sea level anomaly
#   standard_name: sea_surface_height_above_sea_level
#   units: m
# Variable: latitude
#   axis: Y
#   bounds: lat_bnds
#   long_name: Latitude
#   standard_name: latitude
#   units: degrees_north
#   valid_max: 64.875
#   valid_min: 49.125
# Variable: longitude
#   axis: X
#   bounds: lon_bnds
#   long_name: Longitude
#   standard_name: longitude
#   units: degrees_east
#   valid_max: -9.375
#   valid_min: -36.625
# Variable: time
#   valid_min: 27173
#   valid_max: 27173
# File: cmems_sea_level-sla-1d-20240526_20240526-nrt.nc
# Base Name: cmems_sea_level-sla-1d-20240526_20240526-nrt.nc
# Key Variable: sla
# Global attributes:
#   Conventions: CF-1.6
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   cdm_data_type: Grid
#   comment: Sea Surface Height measured by Altimetry and derived variables
#   contact: servicedesk.cmems@mercator-ocean.eu
#   creator_email: servicedesk.cmems@mercator-ocean.eu
#   creator_name: CMEMS - Sea Level Thematic Assembly Center
#   creator_url: http://marine.copernicus.eu
#   date_created: 2023-11-24T00:53:06Z
#   date_issued: 2023-11-24T00:53:06Z
#   date_modified: 2023-11-24T00:53:06Z
#   geospatial_lat_max: 89.875
#   geospatial_lat_min: -89.875
#   geospatial_lat_resolution: 0.25
#   geospatial_lat_units: degrees_north
#   geospatial_lon_max: 179.875
#   geospatial_lon_min: -179.875
#   geospatial_lon_resolution: 0.25
#   geospatial_lon_units: degrees_east
#   geospatial_vertical_max: 0.0
#   geospatial_vertical_min: 0.0
#   geospatial_vertical_positive: down
#   geospatial_vertical_resolution: point
#   geospatial_vertical_units: m
#   history: 2023-11-24 00:53:07Z: Creation
#   institution: CLS, CNES
#   keywords: Oceans > Ocean Topography > Sea Surface Height
#   keywords_vocabulary: NetCDF COARDS Climate and Forecast Standard Names
#   license: http://marine.copernicus.eu/web/27-service-commitments-and-licence.php
#   platform: Altika, Cryosat-2 New Orbit, Haiyang-2B, Jason-3 Interleaved, Sentinel-3A, Sentinel-3B, Sentinel-6A
#   processing_level: L4
#   product_version: vDec2021
#   project: COPERNICUS MARINE ENVIRONMENT MONITORING SERVICE (CMEMS)
#   references: http://marine.copernicus.eu
#   software_version: 19.2.0_DUACS_DT2021_baseline
#   source: Altimetry measurements
#   ssalto_duacs_comment: Sentinel-6A is the reference mission used for the altimeter inter-calibration processing
#   standard_name_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention Standard Name Table v37
#   summary: SSALTO/DUACS Near-Real-Time Level-4 sea surface height and derived variables measured by multi-satellite altimetry observations over Global Ocean.
#   time_coverage_duration: P1D
#   time_coverage_end: 2023-11-24T12:00:00Z
#   time_coverage_resolution: P1D
#   time_coverage_start: 2023-11-23T12:00:00Z
#   title: NRT merged all satellites Global Ocean Gridded SSALTO/DUACS Sea Surface Height L4 product and derived variables
#   copernicusmarine_version: 1.2.0
#
# Variable attributes:
# Variable: sla
#   ancillary_variables: err_sla
#   comment: The sea level anomaly is the sea surface height above mean sea surface; it is referenced to the [1993, 2012] period; see the product user manual for details
#   grid_mapping: crs
#   long_name: Sea level anomaly
#   standard_name: sea_surface_height_above_sea_level
#   units: m
# Variable: latitude
#   axis: Y
#   bounds: lat_bnds
#   long_name: Latitude
#   standard_name: latitude
#   units: degrees_north
#   valid_max: 64.875
#   valid_min: 49.125
# Variable: longitude
#   axis: X
#   bounds: lon_bnds
#   long_name: Longitude
#   standard_name: longitude
#   units: degrees_east
#   valid_max: -9.375
#   valid_min: -36.625
# Variable: time
#   valid_min: 27174
#   valid_max: 27174
# File: cmems_sea_level-sla-1d-20240527_20240527-nrt.nc
# Base Name: cmems_sea_level-sla-1d-20240527_20240527-nrt.nc
# Key Variable: sla
# Global attributes:
#   Conventions: CF-1.6
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   cdm_data_type: Grid
#   comment: Sea Surface Height measured by Altimetry and derived variables
#   contact: servicedesk.cmems@mercator-ocean.eu
#   creator_email: servicedesk.cmems@mercator-ocean.eu
#   creator_name: CMEMS - Sea Level Thematic Assembly Center
#   creator_url: http://marine.copernicus.eu
#   date_created: 2023-11-24T00:53:06Z
#   date_issued: 2023-11-24T00:53:06Z
#   date_modified: 2023-11-24T00:53:06Z
#   geospatial_lat_max: 89.875
#   geospatial_lat_min: -89.875
#   geospatial_lat_resolution: 0.25
#   geospatial_lat_units: degrees_north
#   geospatial_lon_max: 179.875
#   geospatial_lon_min: -179.875
#   geospatial_lon_resolution: 0.25
#   geospatial_lon_units: degrees_east
#   geospatial_vertical_max: 0.0
#   geospatial_vertical_min: 0.0
#   geospatial_vertical_positive: down
#   geospatial_vertical_resolution: point
#   geospatial_vertical_units: m
#   history: 2023-11-24 00:53:07Z: Creation
#   institution: CLS, CNES
#   keywords: Oceans > Ocean Topography > Sea Surface Height
#   keywords_vocabulary: NetCDF COARDS Climate and Forecast Standard Names
#   license: http://marine.copernicus.eu/web/27-service-commitments-and-licence.php
#   platform: Altika, Cryosat-2 New Orbit, Haiyang-2B, Jason-3 Interleaved, Sentinel-3A, Sentinel-3B, Sentinel-6A
#   processing_level: L4
#   product_version: vDec2021
#   project: COPERNICUS MARINE ENVIRONMENT MONITORING SERVICE (CMEMS)
#   references: http://marine.copernicus.eu
#   software_version: 19.2.0_DUACS_DT2021_baseline
#   source: Altimetry measurements
#   ssalto_duacs_comment: Sentinel-6A is the reference mission used for the altimeter inter-calibration processing
#   standard_name_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention Standard Name Table v37
#   summary: SSALTO/DUACS Near-Real-Time Level-4 sea surface height and derived variables measured by multi-satellite altimetry observations over Global Ocean.
#   time_coverage_duration: P1D
#   time_coverage_end: 2023-11-24T12:00:00Z
#   time_coverage_resolution: P1D
#   time_coverage_start: 2023-11-23T12:00:00Z
#   title: NRT merged all satellites Global Ocean Gridded SSALTO/DUACS Sea Surface Height L4 product and derived variables
#   copernicusmarine_version: 1.2.0
#
# Variable attributes:
# Variable: sla
#   ancillary_variables: err_sla
#   comment: The sea level anomaly is the sea surface height above mean sea surface; it is referenced to the [1993, 2012] period; see the product user manual for details
#   grid_mapping: crs
#   long_name: Sea level anomaly
#   standard_name: sea_surface_height_above_sea_level
#   units: m
# Variable: latitude
#   axis: Y
#   bounds: lat_bnds
#   long_name: Latitude
#   standard_name: latitude
#   units: degrees_north
#   valid_max: 64.875
#   valid_min: 49.125
# Variable: longitude
#   axis: X
#   bounds: lon_bnds
#   long_name: Longitude
#   standard_name: longitude
#   units: degrees_east
#   valid_max: -9.375
#   valid_min: -36.625
# Variable: time
#   valid_min: 27175
#   valid_max: 27175
# File: olci_a_1km-CHL_OC4ME-1d-20240520_20240520-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240520_20240520-nrt.nc
# Key Variable: CHL_OC4ME
# File: olci_b_1km-CHL_OC4ME-1d-20240520_20240520-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240520_20240520-nrt.nc
# Key Variable: CHL_OC4ME
# Global attributes:
#   site_name: User defined area of interest
#   citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   creation_date: Tue May 21 15:33:58 2024
#   easternmost_longitude: -9.269
#   creator_url: http://rsg.pml.ac.uk
#   references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   keywords: satellite,observation,ocean
#   summary: These data are Level-3 satellite observation data (Level 3 meaning raw observations processed to geophysical quantities, and placed onto a regular grid).
#   id: M2024141-2024141.noCode.all.OEB.median.20may24-20may24.v1.20241421517.data.nc
#   naming_authority: uk.ac.pml
#   geospatial_lat_max: 65.0
#   title: Composited Level-3 satellite data
#   source: Ocean and Land Colour Instrument
#   northernmost_latitude: 65.0
#   creator_name: Plymouth Marine Laboratory Remote Sensing Group
#   processing_level: Level-3 (NASA EOS Conventions)
#   creator_email: rsghelp@pml.ac.uk
#   date_issued: Tue May 21 15:33:58 2024
#   geospatial_lat_min: 49.0
#   date_created: Tue May 21 15:33:58 2024
#   institution: Plymouth Marine Laboratory Remote Sensing Group
#   geospatial_lon_max: -9.269
#   geospatial_lon_min: -36.87
#   contact1: email: rsghelp@pml.ac.uk
#   license: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   Conventions: CF-1.4
#   project: NEODAAS (NERC Earth Observation Data Acquisition and Analysis Service)
#   cdm_data_type: Grid
#   RSG_sensor: OLCI
#   westernmost_longitude: -36.87
#   RSG_areacode: noCode
#   southernmost_latitude: 49.0
#   history: 1716301053 Created by compositing together the following files in median mode: /tmp/netcdf_compositor_44fthb4m/M2024141.1229.G13.all.OEB.20may241229.v1.20241411229.data.nc, /tmp/netcdf_compositor_44fthb4m/M2024141.0907.G13.all.OEB.20may240907.v1.20241410907.data.nc, /tmp/netcdf_compositor_44fthb4m/M2024141.1410.G13.all.OEB.20may241410.v1.20241411410.data.nc, /tmp/netcdf_compositor_44fthb4m/M2024141.1048.G13.all.OEB.20may241048.v1.20241411048.data.nc
#   RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable attributes:
# Variable: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
# Variable: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
# Variable: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
# Variable: CHL_OC4ME
#   long_name: Chlorophyll-a concentration in sea water as measured by the OLCI sensor
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
# File: olci_a_1km-CHL_OC4ME-1d-20240521_20240521-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240521_20240521-nrt.nc
# Key Variable: CHL_OC4ME
# File: olci_b_1km-CHL_OC4ME-1d-20240521_20240521-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240521_20240521-nrt.nc
# Key Variable: CHL_OC4ME
# Global attributes:
#   site_name: User defined area of interest
#   citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   creation_date: Wed May 22 15:38:32 2024
#   easternmost_longitude: -9.269
#   creator_url: http://rsg.pml.ac.uk
#   references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   keywords: satellite,observation,ocean
#   summary: These data are Level-3 satellite observation data (Level 3 meaning raw observations processed to geophysical quantities, and placed onto a regular grid).
#   id: M2024142-2024142.noCode.all.OEB.median.21may24-21may24.v1.20241431516.data.nc
#   naming_authority: uk.ac.pml
#   geospatial_lat_max: 65.0
#   title: Composited Level-3 satellite data
#   source: Ocean and Land Colour Instrument
#   northernmost_latitude: 65.0
#   creator_name: Plymouth Marine Laboratory Remote Sensing Group
#   processing_level: Level-3 (NASA EOS Conventions)
#   creator_email: rsghelp@pml.ac.uk
#   date_issued: Wed May 22 15:38:32 2024
#   geospatial_lat_min: 49.0
#   date_created: Wed May 22 15:38:32 2024
#   institution: Plymouth Marine Laboratory Remote Sensing Group
#   geospatial_lon_max: -9.269
#   geospatial_lon_min: -36.87
#   contact1: email: rsghelp@pml.ac.uk
#   license: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   Conventions: CF-1.4
#   project: NEODAAS (NERC Earth Observation Data Acquisition and Analysis Service)
#   cdm_data_type: Grid
#   RSG_sensor: OLCI
#   westernmost_longitude: -36.87
#   RSG_areacode: noCode
#   southernmost_latitude: 49.0
#   history: 1716387379 Created by compositing together the following files in median mode: /tmp/netcdf_compositor_62pll6sv/M2024142.1203.G13.all.OEB.21may241203.v1.20241421203.data.nc, /tmp/netcdf_compositor_62pll6sv/M2024142.0841.G13.all.OEB.21may240841.v1.20241420841.data.nc, /tmp/netcdf_compositor_62pll6sv/M2024142.1022.G13.all.OEB.21may241022.v1.20241421022.data.nc, /tmp/netcdf_compositor_62pll6sv/M2024142.1344.G13.all.OEB.21may241344.v1.20241421344.data.nc
#   RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable attributes:
# Variable: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
# Variable: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
# Variable: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
# Variable: CHL_OC4ME
#   long_name: Chlorophyll-a concentration in sea water as measured by the OLCI sensor
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
# File: olci_a_1km-CHL_OC4ME-1d-20240522_20240522-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240522_20240522-nrt.nc
# Key Variable: CHL_OC4ME
# File: olci_b_1km-CHL_OC4ME-1d-20240522_20240522-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240522_20240522-nrt.nc
# Key Variable: CHL_OC4ME
# Global attributes:
#   site_name: User defined area of interest
#   citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   creation_date: Thu May 23 15:37:13 2024
#   easternmost_longitude: -9.269
#   creator_url: http://rsg.pml.ac.uk
#   references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   keywords: satellite,observation,ocean
#   summary: These data are Level-3 satellite observation data (Level 3 meaning raw observations processed to geophysical quantities, and placed onto a regular grid).
#   id: M2024143-2024143.noCode.all.OEB.median.22may24-22may24.v1.20241441445.data.nc
#   naming_authority: uk.ac.pml
#   geospatial_lat_max: 65.0
#   title: Composited Level-3 satellite data
#   source: Ocean and Land Colour Instrument
#   northernmost_latitude: 65.0
#   creator_name: Plymouth Marine Laboratory Remote Sensing Group
#   processing_level: Level-3 (NASA EOS Conventions)
#   creator_email: rsghelp@pml.ac.uk
#   date_issued: Thu May 23 15:37:13 2024
#   geospatial_lat_min: 49.0
#   date_created: Thu May 23 15:37:13 2024
#   institution: Plymouth Marine Laboratory Remote Sensing Group
#   geospatial_lon_max: -9.269
#   geospatial_lon_min: -36.87
#   contact1: email: rsghelp@pml.ac.uk
#   license: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   Conventions: CF-1.4
#   project: NEODAAS (NERC Earth Observation Data Acquisition and Analysis Service)
#   cdm_data_type: Grid
#   RSG_sensor: OLCI
#   westernmost_longitude: -36.87
#   RSG_areacode: noCode
#   southernmost_latitude: 49.0
#   history: 1716471946 Created by compositing together the following files in median mode: /tmp/netcdf_compositor_6kwzoa08/M2024143.1137.G13.all.OEB.22may241137.v1.20241431137.data.nc, /tmp/netcdf_compositor_6kwzoa08/M2024143.1318.G13.all.OEB.22may241318.v1.20241431318.data.nc, /tmp/netcdf_compositor_6kwzoa08/M2024143.0956.G13.all.OEB.22may240956.v1.20241430956.data.nc
#   RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable attributes:
# Variable: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
# Variable: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
# Variable: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
# Variable: CHL_OC4ME
#   long_name: Chlorophyll-a concentration in sea water as measured by the OLCI sensor
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
# File: olci_a_1km-CHL_OC4ME-1d-20240523_20240523-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240523_20240523-nrt.nc
# Key Variable: CHL_OC4ME
# File: olci_b_1km-CHL_OC4ME-1d-20240523_20240523-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240523_20240523-nrt.nc
# Key Variable: CHL_OC4ME
# Global attributes:
#   site_name: User defined area of interest
#   citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   creation_date: Fri May 24 10:03:38 2024
#   easternmost_longitude: -9.269
#   creator_url: http://rsg.pml.ac.uk
#   references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   keywords: satellite,observation,ocean
#   summary: These data are Level-3 satellite observation data (Level 3 meaning raw observations processed to geophysical quantities, and placed onto a regular grid).
#   id: M2024144-2024144.noCode.all.OEB.median.23may24-23may24.v1.20241450945.data.nc
#   naming_authority: uk.ac.pml
#   geospatial_lat_max: 65.0
#   title: Composited Level-3 satellite data
#   source: Ocean and Land Colour Instrument
#   northernmost_latitude: 65.0
#   creator_name: Plymouth Marine Laboratory Remote Sensing Group
#   processing_level: Level-3 (NASA EOS Conventions)
#   creator_email: rsghelp@pml.ac.uk
#   date_issued: Fri May 24 10:03:38 2024
#   geospatial_lat_min: 49.0
#   date_created: Fri May 24 10:03:38 2024
#   institution: Plymouth Marine Laboratory Remote Sensing Group
#   geospatial_lon_max: -9.269
#   geospatial_lon_min: -36.87
#   contact1: email: rsghelp@pml.ac.uk
#   license: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   Conventions: CF-1.4
#   project: NEODAAS (NERC Earth Observation Data Acquisition and Analysis Service)
#   cdm_data_type: Grid
#   RSG_sensor: OLCI
#   westernmost_longitude: -36.87
#   RSG_areacode: noCode
#   southernmost_latitude: 49.0
#   history: 1716540316 Created by compositing together the following files in median mode: /tmp/netcdf_compositor_djim5mmh/M2024144.1111.G13.all.OEB.23may241111.v1.20241441111.data.nc, /tmp/netcdf_compositor_djim5mmh/M2024144.1433.G13.all.OEB.23may241433.v1.20241441433.data.nc, /tmp/netcdf_compositor_djim5mmh/M2024144.0930.G13.all.OEB.23may240930.v1.20241440930.data.nc, /tmp/netcdf_compositor_djim5mmh/M2024144.1252.G13.all.OEB.23may241252.v1.20241441252.data.nc
#   RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable attributes:
# Variable: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
# Variable: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
# Variable: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
# Variable: CHL_OC4ME
#   long_name: Chlorophyll-a concentration in sea water as measured by the OLCI sensor
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
# File: olci_a_1km-CHL_OC4ME-1d-20240524_20240524-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240524_20240524-nrt.nc
# Key Variable: CHL_OC4ME
# File: olci_b_1km-CHL_OC4ME-1d-20240524_20240524-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240524_20240524-nrt.nc
# Key Variable: CHL_OC4ME
# Global attributes:
#   site_name: User defined area of interest
#   citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   creation_date: Sat May 25 07:43:52 2024
#   easternmost_longitude: -9.269
#   creator_url: http://rsg.pml.ac.uk
#   references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   keywords: satellite,observation,ocean
#   summary: These data are Level-3 satellite observation data (Level 3 meaning raw observations processed to geophysical quantities, and placed onto a regular grid).
#   id: M2024145-2024145.noCode.all.OEB.median.24may24-24may24.v1.20241460715.data.nc
#   naming_authority: uk.ac.pml
#   geospatial_lat_max: 65.0
#   title: Composited Level-3 satellite data
#   source: Ocean and Land Colour Instrument
#   northernmost_latitude: 65.0
#   creator_name: Plymouth Marine Laboratory Remote Sensing Group
#   processing_level: Level-3 (NASA EOS Conventions)
#   creator_email: rsghelp@pml.ac.uk
#   date_issued: Sat May 25 07:43:52 2024
#   geospatial_lat_min: 49.0
#   date_created: Sat May 25 07:43:52 2024
#   institution: Plymouth Marine Laboratory Remote Sensing Group
#   geospatial_lon_max: -9.269
#   geospatial_lon_min: -36.87
#   contact1: email: rsghelp@pml.ac.uk
#   license: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   Conventions: CF-1.4
#   project: NEODAAS (NERC Earth Observation Data Acquisition and Analysis Service)
#   cdm_data_type: Grid
#   RSG_sensor: OLCI
#   westernmost_longitude: -36.87
#   RSG_areacode: noCode
#   southernmost_latitude: 49.0
#   history: 1716617752 Created by compositing together the following files in median mode: /tmp/netcdf_compositor_pmlbyf8y/M2024145.0903.G13.all.OEB.24may240903.v1.20241450903.data.nc, /tmp/netcdf_compositor_pmlbyf8y/M2024145.1225.G13.all.OEB.24may241225.v1.20241451225.data.nc, /tmp/netcdf_compositor_pmlbyf8y/M2024145.1044.G13.all.OEB.24may241044.v1.20241451044.data.nc, /tmp/netcdf_compositor_pmlbyf8y/M2024145.1406.G13.all.OEB.24may241406.v1.20241451406.data.nc
#   RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable attributes:
# Variable: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
# Variable: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
# Variable: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
# Variable: CHL_OC4ME
#   long_name: Chlorophyll-a concentration in sea water as measured by the OLCI sensor
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
# File: olci_a_1km-CHL_OC4ME-1d-20240525_20240525-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240525_20240525-nrt.nc
# Key Variable: CHL_OC4ME
# File: olci_b_1km-CHL_OC4ME-1d-20240525_20240525-nrt.nc
# Base Name: olci__1km-CHL_OC4ME-1d-20240525_20240525-nrt.nc
# Key Variable: CHL_OC4ME
# Global attributes:
#   site_name: User defined area of interest
#   citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   creation_date: Sun May 26 09:10:00 2024
#   easternmost_longitude: -9.269
#   creator_url: http://rsg.pml.ac.uk
#   references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   keywords: satellite,observation,ocean
# ...
#   RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable attributes:
# Variable: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
# Variable: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
# Variable: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
# Variable: chl_oc5
#   long_name: Chlorophyll-a concentration in sea water using the OC5 algorithm
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
# Variable: pic
#   units: mol m-3
#   grid_mapping: latitude_longitude
#   units_nonstandard: moles/m^3
#   long_name: Particulate Inorganic Carbon
#   cell_methods: time: median
# File: viirs_suomi-chl_oc5_pic-1d-20240526_20240526-nrt.nc
# Base Name: viirs_suomi-chl_oc5_pic-1d-20240526_20240526-nrt.nc
# Key Variable: chl_oc5
# Global attributes:
#   site_name: User defined area of interest
#   citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   creation_date: Mon May 27 07:41:07 2024
#   easternmost_longitude: -9.269
#   creator_url: http://rsg.pml.ac.uk
#   references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   keywords: satellite,observation,ocean
#   summary: These data are Level-3 satellite observation data (Level 3 meaning raw observations processed to geophysical quantities, and placed onto a regular grid).
#   id: M2024147-2024147.noCode.oc_products.VRS.median.26may24-26may24.v1.20241480716.data.nc
#   naming_authority: uk.ac.pml
#   geospatial_lat_max: 65.0
#   title: Composited Level-3 satellite data
#   source: Visible Infrared Imaging Suite
#   northernmost_latitude: 65.0
#   creator_name: Plymouth Marine Laboratory Remote Sensing Group
#   processing_level: Level-3 (NASA EOS Conventions)
#   creator_email: rsghelp@pml.ac.uk
#   date_issued: Mon May 27 07:41:07 2024
#   geospatial_lat_min: 49.0
#   date_created: Mon May 27 07:41:07 2024
#   institution: Plymouth Marine Laboratory Remote Sensing Group
#   geospatial_lon_max: -9.269
#   geospatial_lon_min: -36.87
#   contact1: email: rsghelp@pml.ac.uk
#   license: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   Conventions: CF-1.4
#   project: NEODAAS (NERC Earth Observation Data Acquisition and Analysis Service)
#   cdm_data_type: Grid
#   RSG_sensor: VIIRS
#   westernmost_longitude: -36.87
#   RSG_areacode: noCode
#   southernmost_latitude: 49.0
#   history: 1716790564 Created by compositing together the following files in median mode: /tmp/netcdf_compositor_3z_udv3o/M2024147.0148.G13.oc_products.VRS.26may240148.v1.20241470148.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1324.G13.oc_products.VRS.26may241324.v1.20241471324.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1130.G13.oc_products.VRS.26may241130.v1.20241471130.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1500.G13.oc_products.VRS.26may241500.v1.20241471500.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0006.G13.oc_products.VRS.26may240006.v1.20241470006.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0500.G13.oc_products.VRS.26may240500.v1.20241470500.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1000.G13.oc_products.VRS.26may241000.v1.20241471000.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1630.G13.oc_products.VRS.26may241630.v1.20241471630.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0954.G13.oc_products.VRS.26may240954.v1.20241470954.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1136.G13.oc_products.VRS.26may241136.v1.20241471136.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0642.G13.oc_products.VRS.26may240642.v1.20241470642.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0648.G13.oc_products.VRS.26may240648.v1.20241470648.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1318.G13.oc_products.VRS.26may241318.v1.20241471318.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0818.G13.oc_products.VRS.26may240818.v1.20241470818.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0000.G13.oc_products.VRS.26may240000.v1.20241470000.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1454.G13.oc_products.VRS.26may241454.v1.20241471454.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1642.G13.oc_products.VRS.26may241642.v1.20241471642.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0824.G13.oc_products.VRS.26may240824.v1.20241470824.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0506.G13.oc_products.VRS.26may240506.v1.20241470506.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1142.G13.oc_products.VRS.26may241142.v1.20241471142.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0142.G13.oc_products.VRS.26may240142.v1.20241470142.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.0324.G13.oc_products.VRS.26may240324.v1.20241470324.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1636.G13.oc_products.VRS.26may241636.v1.20241471636.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1312.G13.oc_products.VRS.26may241312.v1.20241471312.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1448.G13.oc_products.VRS.26may241448.v1.20241471448.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1124.G13.oc_products.VRS.26may241124.v1.20241471124.data.nc, /tmp/netcdf_compositor_3z_udv3o/M2024147.1306.G13.oc_products.VRS.26may241306.v1.20241471306.data.nc
#   RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable attributes:
# Variable: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
# Variable: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
# Variable: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
# Variable: chl_oc5
#   long_name: Chlorophyll-a concentration in sea water using the OC5 algorithm
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
# Variable: pic
#   units: mol m-3
#   grid_mapping: latitude_longitude
#   units_nonstandard: moles/m^3
#   long_name: Particulate Inorganic Carbon
#   cell_methods: time: median
# File: viirs_suomi-chl_oc5_pic-1d-20240527_20240527-nrt.nc
# Base Name: viirs_suomi-chl_oc5_pic-1d-20240527_20240527-nrt.nc
# Key Variable: chl_oc5
# Global attributes:
#   site_name: User defined area of interest
#   citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   creation_date: Tue May 28 07:39:02 2024
#   easternmost_longitude: -9.269
#   creator_url: http://rsg.pml.ac.uk
#   references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
#   Metadata_Conventions: Unidata Dataset Discovery v1.0
#   keywords: satellite,observation,ocean
#   summary: These data are Level-3 satellite observation data (Level 3 meaning raw observations processed to geophysical quantities, and placed onto a regular grid).
#   id: M2024148-2024148.noCode.oc_products.VRS.median.27may24-27may24.v1.20241490716.data.nc
#   naming_authority: uk.ac.pml
#   geospatial_lat_max: 65.0
#   title: Composited Level-3 satellite data
#   source: Visible Infrared Imaging Suite
#   northernmost_latitude: 65.0
#   creator_name: Plymouth Marine Laboratory Remote Sensing Group
#   processing_level: Level-3 (NASA EOS Conventions)
#   creator_email: rsghelp@pml.ac.uk
#   date_issued: Tue May 28 07:39:02 2024
#   geospatial_lat_min: 49.0
#   date_created: Tue May 28 07:39:02 2024
#   institution: Plymouth Marine Laboratory Remote Sensing Group
#   geospatial_lon_max: -9.269
#   geospatial_lon_min: -36.87
#   contact1: email: rsghelp@pml.ac.uk
#   license: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
#   Conventions: CF-1.4
#   project: NEODAAS (NERC Earth Observation Data Acquisition and Analysis Service)
#   cdm_data_type: Grid
#   RSG_sensor: VIIRS
#   westernmost_longitude: -36.87
#   RSG_areacode: noCode
#   southernmost_latitude: 49.0
#   history: 1716876970 Created by compositing together the following files in median mode: /tmp/netcdf_compositor_skq67pqs/M2024148.0936.G13.oc_products.VRS.27may240936.v1.20241480936.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0448.G13.oc_products.VRS.27may240448.v1.20241480448.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1254.G13.oc_products.VRS.27may241254.v1.20241481254.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0124.G13.oc_products.VRS.27may240124.v1.20241480124.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1618.G13.oc_products.VRS.27may241618.v1.20241481618.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0306.G13.oc_products.VRS.27may240306.v1.20241480306.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0442.G13.oc_products.VRS.27may240442.v1.20241480442.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1248.G13.oc_products.VRS.27may241248.v1.20241481248.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1442.G13.oc_products.VRS.27may241442.v1.20241481442.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0800.G13.oc_products.VRS.27may240800.v1.20241480800.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1624.G13.oc_products.VRS.27may241624.v1.20241481624.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0624.G13.oc_products.VRS.27may240624.v1.20241480624.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1306.G13.oc_products.VRS.27may241306.v1.20241481306.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1300.G13.oc_products.VRS.27may241300.v1.20241481300.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0806.G13.oc_products.VRS.27may240806.v1.20241480806.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1612.G13.oc_products.VRS.27may241612.v1.20241481612.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1436.G13.oc_products.VRS.27may241436.v1.20241481436.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0630.G13.oc_products.VRS.27may240630.v1.20241480630.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1430.G13.oc_products.VRS.27may241430.v1.20241481430.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1118.G13.oc_products.VRS.27may241118.v1.20241481118.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1124.G13.oc_products.VRS.27may241124.v1.20241481124.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.0942.G13.oc_products.VRS.27may240942.v1.20241480942.data.nc, /tmp/netcdf_compositor_skq67pqs/M2024148.1112.G13.oc_products.VRS.27may241112.v1.20241481112.data.nc
#   RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable attributes:
# Variable: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
# Variable: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
# Variable: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
# Variable: chl_oc5
#   long_name: Chlorophyll-a concentration in sea water using the OC5 algorithm
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
# Variable: pic
#   units: mol m-3
#   grid_mapping: latitude_longitude
#   units_nonstandard: moles/m^3
#   long_name: Particulate Inorganic Carbon
#   cell_methods: time: median

# %%
# Plotting loop

# 130km circle around deploy point
circle_points = generate_circle_points(60, -24, 444)
circle_lats, circle_lons = circle_points[:, 0], circle_points[:, 1]

# Load float positions
float_position_path = os.path.join(floats_dir, 'Float_positions_2024_05_25.csv')
full_position = pd.read_csv(float_position_path)

for var_category, files in var_dict.items():
    for day_offset in [-2, -1]:  # Plot the last two days ### Change this to plot more days. Have as an option as the beginning?
        if len(files) > 1:
            data_vars = []
            for file, data_var in files:
                cur_data_var = xr.open_dataset(os.path.join(NEODASS_dir, f'{file}'))
                data_vars.append(cur_data_var[data_var].isel(time=day_offset))
            aligned_data_vars = xr.align(*data_vars, join='outer')
            combined_data_var = aligned_data_vars[0]
            for var in aligned_data_vars[1:]:
                combined_data_var = combined_data_var.combine_first(var)
            combined_data_var_mean = np.nanmean(combined_data_var, axis=0)
            date_of_plot = str(combined_data_var['time'].data)[0:10]
        elif len(files) == 1:
            file, data_var = files[0]
            cur_data_var = xr.open_dataset(os.path.join(NEODASS_dir, f'{file}'))
            date_of_plot = str(cur_data_var['time'].data[day_offset])[0:10]
        else:
            continue

        # Dependant settings based on each variable type
        if var_category == 'chl':
            xx_plot_units = cur_data_var[data_var].attrs.get('units')
            xx_plot_cbar_label = 'Chlorophyll (' + xx_plot_units + ')'
            xx_plot_min = CHLA_plot_lim_min
            xx_plot_max = CHLA_plot_lim_max
            color = CHLA_color
            log_scaling = CHLA_plot_as_log
            xx_output_dir_name = 'Chla'

        elif var_category == 'temp':
            xx_plot_units = cur_data_var[data_var].attrs.get('units')
            if xx_plot_units == 'kelvin':
                degree_sign = u'\N{DEGREE SIGN}'
                xx_plot_cbar_label = 'Sea Surface Temperature (' + degree_sign + 'C)'
                if len(files) > 1:
                    combined_data_var_mean -= 273.15
                else:
                    cur_data_var[data_var] = cur_data_var[data_var] - 273.15
                xx_plot_min = SST_plot_lim_min
                xx_plot_max = SST_plot_lim_max
                color = SST_color
                log_scaling = SST_plot_as_log
                xx_output_dir_name = 'SST'
                
        elif var_category == 'sla':
            xx_plot_units = cur_data_var[data_var].attrs.get('units')
            xx_plot_cbar_label = 'Sea level anomaly (' + xx_plot_units + ')'
            xx_plot_min = SSH_plot_lim_min
            xx_plot_max = SSH_plot_lim_max
            color = SSH_color
            log_scaling = SSH_plot_as_log
            xx_output_dir_name = 'SLA'

        elif var_category == 'adt':
            xx_plot_units = cur_data_var[data_var].attrs.get('units')
            xx_plot_cbar_label = 'Sea surface velocity (' + xx_plot_units + 's$^{-1}$)'
            xx_plot_min = SSH_plot_lim_min
            xx_plot_max = SSH_plot_lim_max
            color = SSH_color
            log_scaling = SSH_plot_as_log
            xx_output_dir_name = 'SSC'

        else:
            xx_plot_units = cur_data_var[data_var].attrs.get('units')
            xx_plot_cbar_label = 'Particulate backscatter (' + xx_plot_units + ')'
            xx_plot_min = BBP_plot_lim_min
            xx_plot_max = BBP_plot_lim_max
            color = BBP_color
            log_scaling = BBP_plot_as_log
            xx_output_dir_name = 'BBP'

        norm = colors.LogNorm(vmin=xx_plot_min, vmax=xx_plot_max) if log_scaling else colors.Normalize(vmin=xx_plot_min, vmax=xx_plot_max)

        if var_category == 'adt':

            fig = plt.figure(figsize=(15, 15))
            ax = fig.add_subplot(1, 1, 1, projection=ccrs.Mercator())
            ax.set_extent([-30, max_lon, min_lat, max_lat], crs=ccrs.PlateCarree())

            # Extract the lon and lat from the dataset only once
            x = cur_data_var['longitude'].data
            y = cur_data_var['latitude'].data

            #From the U and V vector compute the speed, we use it as our colour map
            u = cur_data_var['ugos'].isel(time=day_offset).data
            v = cur_data_var['vgos'].isel(time=day_offset).data
            speed = np.sqrt(u**2 + v**2)

            #Plot the current vectors field and the coastline
            im = ax.quiver(x, y, u, v, speed, angles='xy', scale_units='xy', cmap='viridis', transform=ccrs.PlateCarree(), regrid_shape=50, width = 0.002)

            cbar = plt.colorbar(im, ax=ax, label=xx_plot_cbar_label)

        else:

            fig = plt.figure(figsize=(20, 10))
            ax = fig.add_subplot(1, 1, 1, projection=ccrs.Mercator())
            ax.set_extent([min_lon, max_lon, min_lat, max_lat], crs=ccrs.PlateCarree())

            if len(files) > 1:
                NEODASS_data_to_plot_1day = np.clip(combined_data_var_mean, xx_plot_min, xx_plot_max)
            else:
                NEODASS_data_to_plot_1day = np.clip(cur_data_var[data_var].isel(time=day_offset).data, xx_plot_min, xx_plot_max)
            
            im = ax.pcolormesh(cur_data_var['longitude'].data, 
                               cur_data_var['latitude'].data, 
                               NEODASS_data_to_plot_1day, 
                               cmap=color, 
                               norm=norm,
                               transform=ccrs.PlateCarree())
        
            cbar = plt.colorbar(im, ax=ax, label=xx_plot_cbar_label)

        # Float plotting section
        # Get the unique float names
        unique_floats = full_position['float'].unique()

        # Store legend handles and labels
        legend_handles = []
        
        # Plot each float's positions
        for float_name in unique_floats:
            float_data = full_position[full_position['float'] == float_name].sort_values(by='JULD', ascending=False)  # Sort in descending order

            # Get the colors and opacities for the points
            rgba_color = to_rgba(float_colors.get(float_name, '#000000'))  # Default to black if not found
            num_positions = len(float_data)
            alphas = np.linspace(1, 0.1, min(num_positions, 9))  # Reverse the opacity gradient

            # Plot the positions and lines, with the first 9 points have a decreasing alpha
            for i, (index, row) in enumerate(float_data.iterrows()):
                alpha = alphas[i] if i < 9 else 0.1
                rgba_color_with_alpha = (*rgba_color[:3], alpha)
                marker_edge_color     = (*rgba_color[:3], alpha)  # Marker edge color follows opacity gradient
                ax.scatter(row['LONGITUDE'], row['LATITUDE'], color=rgba_color_with_alpha, edgecolor=marker_edge_color, transform=ccrs.PlateCarree(), zorder=3)

                if i > 0:
                    prev_row = float_data.iloc[i - 1]
                    ax.plot([prev_row['LONGITUDE'], row['LONGITUDE']],
                            [prev_row['LATITUDE'], row['LATITUDE']],
                            color=rgba_color_with_alpha, transform=ccrs.PlateCarree(), zorder=2)
                    
            # Create a proxy artist for each float
            proxy = plt.Line2D([0], [0], linestyle='-', marker='o', color=float_colors.get(float_name, '#000000'), label=float_name)
            legend_handles.append(proxy)
        
        sc3 = ax.scatter(-24,60,transform=ccrs.PlateCarree(), edgecolors='black', facecolors='none', marker='s')
        ax.plot(circle_lons, circle_lats, transform=ccrs.PlateCarree(), color='black')
        
        gdf_1000.plot(ax=ax, transform=ccrs.PlateCarree(), linewidth=0.5, edgecolor='k', facecolor='none')
        gdf_2000.plot(ax=ax, transform=ccrs.PlateCarree(), linewidth=0.3, edgecolor='k', facecolor='none')

        # Add coastlines
        ax.add_feature(cfeature.COASTLINE)

        # Add lon/lat grid and adjust labels
        gl = ax.gridlines(draw_labels=True, x_inline=False, y_inline=False, crs=ccrs.PlateCarree())
        gl.top_labels = False
        gl.right_labels = False

        # Plot title
        plot_title = f'CMEMS_{xx_output_dir_name} {date_of_plot}'
        ax.set_title(plot_title, fontsize=24)

        # Add legend in
        deploy_point_proxy = plt.Line2D([0], [0], linestyle='none', marker='s', color='black', markersize=10, markerfacecolor='none', label='Deploy Point')
        legend_handles.append(deploy_point_proxy)
        ax.legend(handles=legend_handles, loc='lower left')

        # Save output
        save_dir = os.path.join(output_dir, f'{xx_output_dir_name}{"_log" if log_scaling else ""}')
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        basename_suffix = base_name[:10]
        filename = f'{xx_output_dir_name}{"_log" if log_scaling else ""}_{date_of_plot}_NEODASS.png'
        plt.savefig(os.path.join(save_dir, filename))
        
        plt.clf()
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 17
#      15 for file, data_var in files:
#      16     cur_data_var = xr.open_dataset(os.path.join(NEODASS_dir, f'{file}'))
# ---> 17     data_vars.append(cur_data_var[data_var].isel(time=day_offset))
#      18 aligned_data_vars = xr.align(*data_vars, join='outer')
#      19 combined_data_var = aligned_data_vars[0]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\dataarray.py:1493, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1488     return self._from_temp_dataset(ds)
#    1490 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1491 # lists, or zero or one-dimensional np.ndarray's
# -> 1493 variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1494 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    1496 coords = {}
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\variable.py:1018, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1015 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1017 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1018 return self[key]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\variable.py:785, in Variable.__getitem__(self, key)
#     782 dims, indexer, new_order = self._broadcast_indexes(key)
#     783 indexable = as_indexable(self._data)
# --> 785 data = indexing.apply_indexer(indexable, indexer)
#     787 if new_order:
#     788     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\indexing.py:1002, in apply_indexer(indexable, indexer)
#    1000     return indexable.oindex[indexer]
#    1001 else:
# -> 1002     return indexable[indexer]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\indexing.py:820, in MemoryCachedArray.__getitem__(self, indexer)
#     818 def __getitem__(self, indexer: ExplicitIndexer):
#     819     self._check_and_raise_if_non_basic_indexer(indexer)
# --> 820     return type(self)(_wrap_numpy_scalars(self.array[indexer]))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\indexing.py:770, in CopyOnWriteArray.__getitem__(self, indexer)
#     768 def __getitem__(self, indexer: ExplicitIndexer):
#     769     self._check_and_raise_if_non_basic_indexer(indexer)
# --> 770     return type(self)(_wrap_numpy_scalars(self.array[indexer]))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\indexing.py:645, in LazilyIndexedArray.__getitem__(self, indexer)
#     643 def __getitem__(self, indexer: ExplicitIndexer):
#     644     self._check_and_raise_if_non_basic_indexer(indexer)
# --> 645     return type(self)(self.array, self._updated_key(indexer))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\indexing.py:600, in LazilyIndexedArray._updated_key(self, new_key)
#     598         full_key.append(k)
#     599     else:
# --> 600         full_key.append(_index_indexer_1d(k, next(iter_new_key), size))
#     601 full_key_tuple = tuple(full_key)
#     603 if all(isinstance(k, integer_types + (slice,)) for k in full_key_tuple):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xarray\core\indexing.py:287, in _index_indexer_1d(old_indexer, applied_indexer, size)
#     285         indexer = slice_slice(old_indexer, applied_indexer, size)
#     286     else:
# --> 287         indexer = _expand_slice(old_indexer, size)[applied_indexer]  # type: ignore[assignment]
#     288 else:
#     289     indexer = old_indexer[applied_indexer]
#
# IndexError: index -2 is out of bounds for axis 0 with size 1

# %%
import xarray as xr

# Open the NetCDF file
file_path = 'cmems_sea_level-sla-1d-20240520_20240520-nrt.nc'
ds = xr.open_dataset(os.path.join(NEODASS_dir, file))

# Function to print attributes of a dataset or data variable
def print_attrs(obj, indent=0):
    for attr_name, attr_value in obj.attrs.items():
        print(' ' * indent + f"{attr_name}: {attr_value}")

# Print global attributes
print("Global Attributes:")
print_attrs(ds)

# Print attributes of each data variable
for var_name, var in ds.data_vars.items():
    print(f"\nVariable: {var_name}")
    print_attrs(var, indent=2)

# Print attributes of each coordinate
for coord_name, coord in ds.coords.items():
    print(f"\nCoordinate: {coord_name}")
    print_attrs(coord, indent=2)

# Close the dataset
ds.close()
# Out:
# Global Attributes:
# site_name: User defined area of interest
# citation: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
# creation_date: Tue May 21 15:33:58 2024
# easternmost_longitude: -9.269
# creator_url: http://rsg.pml.ac.uk
# references: See NEODAAS webpages at http://www.neodaas.ac.uk/ or RSG pages at http://rsg.pml.ac.uk/
# Metadata_Conventions: Unidata Dataset Discovery v1.0
# keywords: satellite,observation,ocean
# summary: These data are Level-3 satellite observation data (Level 3 meaning raw observations processed to geophysical quantities, and placed onto a regular grid).
# id: M2024141-2024141.noCode.all.OEB.median.20may24-20may24.v1.20241421517.data.nc
# naming_authority: uk.ac.pml
# geospatial_lat_max: 65.0
# title: Composited Level-3 satellite data
# source: Ocean and Land Colour Instrument
# northernmost_latitude: 65.0
# creator_name: Plymouth Marine Laboratory Remote Sensing Group
# processing_level: Level-3 (NASA EOS Conventions)
# creator_email: rsghelp@pml.ac.uk
# date_issued: Tue May 21 15:33:58 2024
# geospatial_lat_min: 49.0
# date_created: Tue May 21 15:33:58 2024
# institution: Plymouth Marine Laboratory Remote Sensing Group
# geospatial_lon_max: -9.269
# geospatial_lon_min: -36.87
# contact1: email: rsghelp@pml.ac.uk
# license: If you use this data towards any publication, please acknowledge this using: 'The authors thank the NERC Earth Observation Data Acquisition and Analysis Service (NEODAAS) for supplying data for this study' and then email NEODAAS (info@neodaas.ac.uk) with the details. The service relies on users' publications as one measure of success.
# Conventions: CF-1.4
# project: NEODAAS (NERC Earth Observation Data Acquisition and Analysis Service)
# cdm_data_type: Grid
# RSG_sensor: OLCI
# westernmost_longitude: -36.87
# RSG_areacode: noCode
# southernmost_latitude: 49.0
# history: 1716301053 Created by compositing together the following files in median mode: /tmp/netcdf_compositor_44fthb4m/M2024141.1229.G13.all.OEB.20may241229.v1.20241411229.data.nc, /tmp/netcdf_compositor_44fthb4m/M2024141.0907.G13.all.OEB.20may240907.v1.20241410907.data.nc, /tmp/netcdf_compositor_44fthb4m/M2024141.1410.G13.all.OEB.20may241410.v1.20241411410.data.nc, /tmp/netcdf_compositor_44fthb4m/M2024141.1048.G13.all.OEB.20may241048.v1.20241411048.data.nc
# RSG_hash_descriptor: openssl_sha1:1:da39a3ee5e6b4b0d3255bfef95601890afd80709
#
# Variable: latitude_longitude
#   grid_mapping_name: latitude_longitude
#
# Variable: CHL_OC4ME
#   long_name: Chlorophyll-a concentration in sea water as measured by the OLCI sensor
#   standard_name: mass_concentration_of_chlorophyll_a_in_sea_water
#   grid_mapping: latitude_longitude
#   units: milligram m-3
#   units_nonstandard: mg m^-3
#   cell_methods: time: median
#
# Coordinate: time
#   time_origin: 1970-01-01 00:00:00
#   valid_min: 0.0
#   bounds: time_bounds
#   long_name: time
#   standard_name: time
#   axis: T
#
# Coordinate: longitude
#   standard_name: longitude
#   long_name: longitude
#   units: degrees_east
#   axis: X
#   valid_min: -36.86479226415094
#   valid_max: -9.274207735849057
#
# Coordinate: latitude
#   standard_name: latitude
#   long_name: latitude
#   units: degrees_north
#   axis: Y
#   valid_min: 49.005207735849055
#   valid_max: 64.99479226415095
